# %% [markdown]
# #### Importing Relevant Libraries and Frameworks

# %%
# Mounting google drive, for utilizing large data

from google.colab import drive
drive.mount('/content/drive', force_remount = True)
# Out:
# Mounted at /content/drive

# %%
# Read / Write access for neuroimaging file formats
# !pip install nibabel    

# Traversing through directories and folders & Regular Expression Matching
# !pip install os-sys         
# !pip install glob3       
# !pip install split-folders

# ML/DL Frameworks
# !pip install tensorflow 
# !pip install torch
# !pip install keras
# !pip install sklearn
# !pip install scipy
# !pip install segmentation_models_3D

# Plotting, Visualization and Saving
# !pip install matplotlib
# !pip install tifffile

# %%
# !pip install split_folders
# !pip install segmentation_models_3D
# !pip install keras_applications
# Out:
# Collecting split_folders
#   Downloading split_folders-0.4.3-py3-none-any.whl (7.4 kB)
# Installing collected packages: split-folders
# Successfully installed split-folders-0.4.3
# Collecting segmentation_models_3D
#   Downloading segmentation_models_3D-1.0.2-py3-none-any.whl (32 kB)
# Requirement already satisfied: tensorflow>=2.5.0 in /usr/local/lib/python3.7/dist-packages (from segmentation_models_3D) (2.6.0)
# Collecting efficientnet-3D
#   Downloading efficientnet_3D-1.0.1-py3-none-any.whl (14 kB)
# Collecting classification-models-3D
#   Downloading classification_models_3D-1.0.2-py3-none-any.whl (45 kB)
#      |████████████████████████████████| 45 kB 2.7 MB/s
# Requirement already satisfied: termcolor~=1.1.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.5.0->segmentation_models_3D) (1.1.0)
# Requirement already satisfied: absl-py~=0.10 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.5.0->segmentation_models_3D) (0.12.0)
# Requirement already satisfied: keras-preprocessing~=1.1.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.5.0->segmentation_models_3D) (1.1.2)
# Requirement already satisfied: wrapt~=1.12.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.5.0->segmentation_models_3D) (1.12.1)
# Requirement already satisfied: google-pasta~=0.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.5.0->segmentation_models_3D) (0.2.0)
# Requirement already satisfied: astunparse~=1.6.3 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.5.0->segmentation_models_3D) (1.6.3)
# Requirement already satisfied: numpy~=1.19.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.5.0->segmentation_models_3D) (1.19.5)
# Requirement already satisfied: keras~=2.6 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.5.0->segmentation_models_3D) (2.6.0)
# Requirement already satisfied: flatbuffers~=1.12.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.5.0->segmentation_models_3D) (1.12)
# Requirement already satisfied: tensorflow-estimator~=2.6 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.5.0->segmentation_models_3D) (2.6.0)
# Requirement already satisfied: grpcio<2.0,>=1.37.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.5.0->segmentation_models_3D) (1.40.0)
# Requirement already satisfied: six~=1.15.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.5.0->segmentation_models_3D) (1.15.0)
# Requirement already satisfied: opt-einsum~=3.3.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.5.0->segmentation_models_3D) (3.3.0)
# Requirement already satisfied: clang~=5.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.5.0->segmentation_models_3D) (5.0)
# Requirement already satisfied: gast==0.4.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.5.0->segmentation_models_3D) (0.4.0)
# Requirement already satisfied: protobuf>=3.9.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.5.0->segmentation_models_3D) (3.17.3)
# Requirement already satisfied: typing-extensions~=3.7.4 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.5.0->segmentation_models_3D) (3.7.4.3)
# Requirement already satisfied: wheel~=0.35 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.5.0->segmentation_models_3D) (0.37.0)
# Requirement already satisfied: h5py~=3.1.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.5.0->segmentation_models_3D) (3.1.0)
# Requirement already satisfied: tensorboard~=2.6 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.5.0->segmentation_models_3D) (2.6.0)
# Requirement already satisfied: cached-property in /usr/local/lib/python3.7/dist-packages (from h5py~=3.1.0->tensorflow>=2.5.0->segmentation_models_3D) (1.5.2)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.6->tensorflow>=2.5.0->segmentation_models_3D) (1.0.1)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.6->tensorflow>=2.5.0->segmentation_models_3D) (2.23.0)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.6->tensorflow>=2.5.0->segmentation_models_3D) (0.6.1)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.6->tensorflow>=2.5.0->segmentation_models_3D) (0.4.6)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.6->tensorflow>=2.5.0->segmentation_models_3D) (1.8.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.6->tensorflow>=2.5.0->segmentation_models_3D) (3.3.4)
# Requirement already satisfied: google-auth<2,>=1.6.3 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.6->tensorflow>=2.5.0->segmentation_models_3D) (1.35.0)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.6->tensorflow>=2.5.0->segmentation_models_3D) (57.4.0)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from google-auth<2,>=1.6.3->tensorboard~=2.6->tensorflow>=2.5.0->segmentation_models_3D) (4.2.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from google-auth<2,>=1.6.3->tensorboard~=2.6->tensorflow>=2.5.0->segmentation_models_3D) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.7/dist-packages (from google-auth<2,>=1.6.3->tensorboard~=2.6->tensorflow>=2.5.0->segmentation_models_3D) (4.7.2)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard~=2.6->tensorflow>=2.5.0->segmentation_models_3D) (1.3.0)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from markdown>=2.6.8->tensorboard~=2.6->tensorflow>=2.5.0->segmentation_models_3D) (4.8.1)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.7/dist-packages (from pyasn1-modules>=0.2.1->google-auth<2,>=1.6.3->tensorboard~=2.6->tensorflow>=2.5.0->segmentation_models_3D) (0.4.8)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard~=2.6->tensorflow>=2.5.0->segmentation_models_3D) (2021.5.30)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard~=2.6->tensorflow>=2.5.0->segmentation_models_3D) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard~=2.6->tensorflow>=2.5.0->segmentation_models_3D) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard~=2.6->tensorflow>=2.5.0->segmentation_models_3D) (3.0.4)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard~=2.6->tensorflow>=2.5.0->segmentation_models_3D) (3.1.1)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->markdown>=2.6.8->tensorboard~=2.6->tensorflow>=2.5.0->segmentation_models_3D) (3.5.0)
# Installing collected packages: efficientnet-3D, classification-models-3D, segmentation-models-3D
# Successfully installed classification-models-3D-1.0.2 efficientnet-3D-1.0.1 segmentation-models-3D-1.0.2
# Collecting keras_applications
#   Downloading Keras_Applications-1.0.8-py3-none-any.whl (50 kB)
#      |████████████████████████████████| 50 kB 3.1 MB/s
# Requirement already satisfied: h5py in /usr/local/lib/python3.7/dist-packages (from keras_applications) (3.1.0)
# Requirement already satisfied: numpy>=1.9.1 in /usr/local/lib/python3.7/dist-packages (from keras_applications) (1.19.5)
# Requirement already satisfied: cached-property in /usr/local/lib/python3.7/dist-packages (from h5py->keras_applications) (1.5.2)
# Installing collected packages: keras-applications
# Successfully installed keras-applications-1.0.8

# %%
# Importing all of the above

import os
import numpy as np
import nibabel as nib
import glob
import splitfolders
import tensorflow as tf
from tensorflow.keras.utils import to_categorical
import keras
import keras.backend as K
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure
from tifffile import imsave
from scipy.interpolate import RegularGridInterpolator
from sklearn.preprocessing import MinMaxScaler
import segmentation_models_3D as sm
scaler = MinMaxScaler()
# Out:
# Segmentation Models: using `tf.keras` framework.

# %% [markdown]
# #### Data Preprocessing

# %%
t1_list = []
t2_list = []
t1ce_list = []
flair_list = []
mask_list = []
for folder in os.listdir("/content/drive/MyDrive/MICCAI_BraTS2020_TrainingData"):
    for file in os.listdir("/content/drive/MyDrive/MICCAI_BraTS2020_TrainingData/" + folder):
        if (file.endswith("seg.nii.gz")):
            mask_list.append("/content/drive/MyDrive/MICCAI_BraTS2020_TrainingData/" + folder + "/" + file)
        if (file.endswith("t1.nii.gz")):
            t1_list.append("/content/drive/MyDrive/MICCAI_BraTS2020_TrainingData/" + folder + "/" + file)
        if (file.endswith("t2.nii.gz")):
            t2_list.append("/content/drive/MyDrive/MICCAI_BraTS2020_TrainingData/" + folder + "/" + file)
        if (file.endswith("t1ce.nii.gz")):
            t1ce_list.append("/content/drive/MyDrive/MICCAI_BraTS2020_TrainingData/" + folder + "/" + file)
        if (file.endswith("flair.nii.gz")):
            flair_list.append("/content/drive/MyDrive/MICCAI_BraTS2020_TrainingData/" + folder + "/" + file)
t1_list.sort()
t2_list.sort()
t1ce_list.sort()
flair_list.sort()
mask_list.sort()

# %%
print("Paths of Training Data with Index 45 : ")
print("T1 : ", t1_list[45])
print("T2 : ", t2_list[45])
print("T1CE : ", t1ce_list[45])
print("Flair : ", flair_list[45])
print("Mask : ", mask_list[45])
# Out:
# Paths of Training Data with Index 45 :
# T1 :  /content/drive/MyDrive/MICCAI_BraTS2020_TrainingData/BraTS20_Training_046/BraTS20_Training_046_t1.nii.gz
# T2 :  /content/drive/MyDrive/MICCAI_BraTS2020_TrainingData/BraTS20_Training_046/BraTS20_Training_046_t2.nii.gz
# T1CE :  /content/drive/MyDrive/MICCAI_BraTS2020_TrainingData/BraTS20_Training_046/BraTS20_Training_046_t1ce.nii.gz
# Flair :  /content/drive/MyDrive/MICCAI_BraTS2020_TrainingData/BraTS20_Training_046/BraTS20_Training_046_flair.nii.gz
# Mask :  /content/drive/MyDrive/MICCAI_BraTS2020_TrainingData/BraTS20_Training_046/BraTS20_Training_046_seg.nii.gz

# %% [markdown]
# ## Visualizing Data

# %%
curr_input = 45
t1_data = nib.load(t1_list[curr_input]).get_fdata()
t1ce_data = nib.load(t1ce_list[curr_input]).get_fdata()
t2_data = nib.load(t2_list[curr_input]).get_fdata()
flair_data = nib.load(flair_list[curr_input]).get_fdata()
combined_data = np.stack([t1_data, t1ce_data, t2_data, flair_data], axis=3)

# %%
combined_data.shape
# Out:
# (240, 240, 155, 4)

# %%
print("Plotting 50th Slice of Input Data with Index 45 : ")
fig, axarr = plt.subplots(2,2)
fig.set_size_inches(10, 10)
axarr[0,0].imshow(combined_data[:, :, 50, 0])
axarr[0,0].set_title('Native (T1)')
axarr[0,1].imshow(combined_data[:, :, 50, 1])
axarr[0,1].set_title('Post - contrast T1 weighted (T1ce)')
axarr[1,0].imshow(combined_data[:, :, 50, 2])
axarr[1,0].set_title('T2 - weighted (T2)')
axarr[1,1].imshow(combined_data[:, :, 50, 3])
axarr[1,1].set_title('T2 Fluid Attenuated Inversion Recovery (FLAIR)')
# Out:
# Plotting 50th Slice of Input Data with Index 45 :
# Text(0.5, 1.0, 'T2 Fluid Attenuated Inversion Recovery (FLAIR)')

# %%
mask_data = nib.load(mask_list[curr_input]).get_fdata()
mask_data = mask_data.astype(np.uint8)

mask_data[mask_data == 4] = 3

# %%
mask_data.shape
# Out:
# (240, 240, 155)

# %%
plt.imshow(mask_data[:, :, 50])
plt.title("Mask corresponding to Scans")
# Out:
# Text(0.5, 1.0, 'Mask corresponding to Scans')

# %%
combined_data = combined_data[56:184, 56:184, 13:141]
mask_data = mask_data[56:184, 56:184, 13:141]

# %%
print(combined_data.shape)
print(mask_data.shape)
# Out:
# (128, 128, 128, 4)
# (128, 128, 128)

# %%
print("Plotting 50th Slice (now 37th) of Input Data with Index 45 : ")
fig, axarr = plt.subplots(2,2)
fig.set_size_inches(10, 10)
axarr[0,0].imshow(combined_data[:, :, 37, 1])
axarr[0,0].set_title('T1CE')
axarr[0,1].imshow(combined_data[:, :, 37, 2])
axarr[0,1].set_title('T2')
axarr[1,0].imshow(combined_data[:, :, 37, 3])
axarr[1,0].set_title('Flair')
axarr[1,1].imshow(mask_data[:, :, 37])
axarr[1,1].set_title('Mask')
# Out:
# Plotting 50th Slice (now 37th) of Input Data with Index 45 :
# Text(0.5, 1.0, 'Mask')

# %%
val, counts = np.unique(mask_data, return_counts=True)

# %%
val, counts

# %%
num_input_data = len(t1ce_list)
for curr_input in range(0, num_input_data):
    print("Processing Index : ", curr_input)  
    t2_data = nib.load(t2_list[curr_input]).get_fdata()   
    t1ce_data = nib.load(t1ce_list[curr_input]).get_fdata()
    flair_data = nib.load(flair_list[curr_input]).get_fdata()        
    mask_data = nib.load(mask_list[curr_input]).get_fdata()
    mask_data = mask_data.astype(np.uint8)
    mask_data[mask_data == 4] = 3 
    combined_data = np.stack([t1ce_data, t2_data, flair_data], axis=3)
    combined_data = combined_data[56:184, 56:184, 13:141]
    mask_data = mask_data[56:184, 56:184, 13:141]
    val, counts = np.unique(mask_data, return_counts=True)
    if (1 - (counts[0]/counts.sum())) > 0.05:  #At least 3% useful volume with labels that are not 0
        print("Saving Index ", curr_input)
        mask_data = to_categorical(mask_data, num_classes=4)
        np.save('/content/drive/MyDrive/MICCAI_BraTS2020_TrainingData/input_data_3channels/images/image_'+str(curr_input)+'.npy', combined_data)
        np.save('/content/drive/MyDrive/MICCAI_BraTS2020_TrainingData/input_data_3channels/masks/mask_'+str(curr_input)+'.npy', mask_data)

# %%
input_folder = '/content/drive/MyDrive/MICCAI_BraTS2020_TrainingData/input_data_3channels/'
output_folder = '/content/drive/MyDrive/MICCAI_BraTS2020_TrainingData/input_data_128/'
splitfolders.ratio(input_folder, output=output_folder, seed=42, ratio=(.75, .25), group_prefix=None) # default values

# %% [markdown]
# #### Understanding and Visualizing Dataset

# %%
# Defining root directories for Images and Masks

train_img_dir = "/content/drive/MyDrive/MICCAI_BraTS2020_TrainingData/input_data_128/train/images/"
train_mask_dir = "/content/drive/MyDrive/MICCAI_BraTS2020_TrainingData/input_data_128/train/masks/"

# %%
# Collecting Data into NumPy arrays

images = []
masks = []

index = 0
for file in os.listdir(train_img_dir):
    index += 1
    if (index == 30):
        break
    images.append(np.load(train_img_dir + file))
    mask = np.load(train_mask_dir + "mask_" + file[6:])
    
    # Combining the 4 Different Scans available into 1.  
    mask = np.argmax(mask, axis=3)
    masks.append(mask)

images = np.array(images)
masks = np.array(masks)

# %%
# Understanding Dimensions of Data

print("Shape of Images Data : ", images.shape)
print("Shape of Classification Labels corresponding to them : ", masks.shape)
# Out:
# Shape of Images Data :  (29, 128, 128, 128, 3)
# Shape of Classification Labels corresponding to them :  (29, 128, 128, 128)

# %%
# Cross-referencing, as expected, the masks can values out of 0, 1, 2 & 3.

print("Values of Classification Labels can be : ", np.unique(masks.flatten()))
# Out:
# Values of Classification Labels can be :  [0 1 2 3]

# %%
# Define a regrid() function, that helps in resizing an image
# based on interpolation of pixels.

def regrid(data, out_x, out_y):
    m = max(data.shape[0], data.shape[1])
    y = np.linspace(0, 1.0/m, data.shape[0])
    x = np.linspace(0, 1.0/m, data.shape[1])
    interpolating_function = RegularGridInterpolator((y, x), data)

    yv, xv = np.meshgrid(np.linspace(0, 1.0/m, out_y), np.linspace(0, 1.0/m, out_x))

    return interpolating_function((xv, yv))

# %%
# Due to limited computation resources, we minimize the size
# of each image in the 3D Volume from 256 x 256 to 64 x 64.

minimized_size = 64

small_images = []
small_masks = []

for i in range(0, len(images)):
    image = images[i]
    mask = masks[i]
    curr_image = []
    curr_mask = []
    
    for z in range(0, 128):
        image_z_0 = image[:, :, z, 0]
        image_z_1 = image[:, :, z, 1]
        image_z_2 = image[:, :, z, 2]
        image_z_0 = regrid(image_z_0, minimized_size, minimized_size)
        image_z_1 = regrid(image_z_1, minimized_size, minimized_size)
        image_z_2 = regrid(image_z_2, minimized_size, minimized_size)
        curr_depth = np.stack([image_z_0, image_z_1, image_z_2])
        curr_depth = np.moveaxis(curr_depth, -1, 0)
        curr_depth = np.moveaxis(curr_depth, -1, 0)
        curr_image.append(curr_depth)
        mask_z = mask[:, :, z]
        mask_z = np.array(np.round(regrid(mask_z, minimized_size, minimized_size)), dtype = 'uint8')
        curr_mask.append(mask_z)
    
    small_images.append(np.array(curr_image))
    small_masks.append(np.array(curr_mask))

small_images = np.array(small_images)
small_masks = np.array(small_masks)

# %%
# Understanding Dimensions of Processed Data

print("Shape of Images Data : ", small_images.shape)
print("Shape of Classification Labels corresponding to them : ", small_masks.shape)
# Out:
# Shape of Images Data :  (29, 128, 64, 64, 3)
# Shape of Classification Labels corresponding to them :  (29, 128, 64, 64)

# %%
# Plotting Input Image Slices and the given Classification Mask
from matplotlib.pyplot import figure

fig, axarr = plt.subplots(2,2)
fig.set_size_inches(10, 10)
axarr[0,0].imshow(small_images[0, 28, :, :, 0])
axarr[0,0].set_title('Input Scan 1')
axarr[0,1].imshow(small_images[0, 28, :, :, 1])
axarr[0,1].set_title('Input Scan 2')
axarr[1,0].imshow(small_images[0, 28, :, :, 2])
axarr[1,0].set_title('Input Scan 3')
axarr[1,1].imshow(small_masks[0, 28, :, :])
axarr[1,1].set_title('Output Classification')

# %%
categorical_example = to_categorical(small_masks[0, 28, :, :], num_classes = 4)

# %%
categorical_example[:, :, 0].shape

# %%
plt.imshow(categorical_example[:, :, 0])

# %%
fig, axarr = plt.subplots(1, 4)
fig.set_size_inches(18, 10)
axarr[0].imshow(categorical_example[:, :, 0])
axarr[0].set_title('Unmarked Volume')
axarr[1].imshow(categorical_example[:, :, 1])
axarr[1].set_title('Necrotic and non-enhancing tumor core (NCR/NET)')
axarr[2].imshow(categorical_example[:, :, 2])
axarr[2].set_title('Peritumoral edema')
axarr[3].imshow(categorical_example[:, :, 3])
axarr[3].set_title('GD-enhancing tumor')

# %%
# Dividing Processed Scans into Training and Testing Data
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split (small_images,
                                                     small_masks,
                                                     test_size=0.15,
                                                     shuffle=True)

# %%
# Converting 3D Scans to 2D Scans, to pass through traditional 2D U-Net

X_train = np.array(X_train.reshape(X_train.shape[0] * 128, minimized_size, minimized_size, 3))
y_train = np.array(y_train.reshape(y_train.shape[0] * 128, minimized_size, minimized_size))
y_train_cat = to_categorical(y_train, num_classes = 4)
X_test = np.array(X_test.reshape(X_test.shape[0] * 128, minimized_size, minimized_size, 3))
y_test = np.array(y_test.reshape(y_test.shape[0] * 128, minimized_size, minimized_size))
y_test_cat = to_categorical(y_test, num_classes = 4)

# %%
# Understanding Dimensions of Processed Data

print("Training Data Input Shape : ", X_train.shape)
print("Training Data Output Shape : ", y_train_cat.shape)

print(" ")

print("Testing Data Input Shape : ", X_test.shape)
print("Testing Data Output Shape : ", y_test_cat.shape)

# %%
# Plotting Input Image Slices and the given Classification Mask

fig, axarr = plt.subplots(2,2)
fig.set_size_inches(10, 10)
axarr[0,0].imshow(y_train_cat[64, :, :, 0])
axarr[0,0].set_title('Class Label : 0')
axarr[0,1].imshow(y_train_cat[64, :, :, 1])
axarr[0,1].set_title('Class Label : 1')
axarr[1,0].imshow(y_train_cat[64, :, :, 2])
axarr[1,0].set_title('Class Label : 2')
axarr[1,1].imshow(y_train_cat[64, :, :, 3])
axarr[1,1].set_title('Class Label : 3')

# %%
def standardUNet2D (num_classes = 4, img_h = 64, img_w = 64, img_ch = 3):
    
    input = keras.layers.Input((img_h, img_w, img_ch))
    
    conv_1 = keras.layers.Conv2D (16, (3, 3), activation = 'relu', padding = 'same') (input)
    conv_1 = keras.layers.Dropout (0.1) (conv_1)
    conv_1 = keras.layers.Conv2D (16, (3, 3), activation = 'relu', padding = 'same') (input)
    pool_1 = keras.layers.MaxPooling2D ((2, 2)) (conv_1)

    conv_2 = keras.layers.Conv2D (32, (3, 3), activation = 'relu', padding = 'same') (pool_1)
    conv_2 = keras.layers.Dropout (0.1) (conv_2)
    conv_2 = keras.layers.Conv2D (32, (3, 3), activation = 'relu', padding = 'same') (conv_2)
    pool_2 = keras.layers.MaxPooling2D ((2, 2)) (conv_2)

    conv_3 = keras.layers.Conv2D (64, (3, 3), activation = 'relu', padding = 'same') (pool_2)
    conv_3 = keras.layers.Dropout (0.2) (conv_3)
    conv_3 = keras.layers.Conv2D (64, (3, 3), activation = 'relu', padding = 'same') (conv_3)
    pool_3 = keras.layers.MaxPooling2D ((2, 2)) (conv_3)

    conv_4 = keras.layers.Conv2D (128, (3, 3), activation = 'relu', padding = 'same') (pool_3)
    conv_4 = keras.layers.Dropout (0.2) (conv_4)
    conv_4 = keras.layers.Conv2D (128, (3, 3), activation = 'relu', padding = 'same') (conv_4)
    pool_4 = keras.layers.MaxPooling2D ((2, 2)) (conv_4)

    conv_5 = keras.layers.Conv2D (256, (3, 3), activation = 'relu', padding = 'same') (pool_4)
    conv_5 = keras.layers.Dropout (0.3) (conv_5)
    conv_5 = keras.layers.Conv2D (256, (3, 3), activation = 'relu', padding = 'same') (conv_5)

    upsample_6 = keras.layers.Conv2DTranspose(128, (2, 2), strides=(2, 2), padding='same')(conv_5)
    upsample_6 = keras.layers.concatenate([upsample_6, conv_4])
    conv_6 = keras.layers.Conv2D(128, (3, 3), activation='relu', padding='same')(upsample_6)
    conv_6 = keras.layers.Dropout(0.2)(conv_6)
    conv_6 = keras.layers.Conv2D(128, (3, 3), activation='relu', padding='same')(conv_6)

    upsample_7 = keras.layers.Conv2DTranspose(64, (2, 2), strides=(2, 2), padding='same')(conv_6)
    upsample_7 = keras.layers.concatenate([upsample_7, conv_3])
    conv_7 = keras.layers.Conv2D(64, (3, 3), activation='relu', padding='same')(upsample_7)
    conv_7 = keras.layers.Dropout(0.2)(conv_7)
    conv_7 = keras.layers.Conv2D(64, (3, 3), activation='relu', padding='same')(conv_7)

    upsample_8 = keras.layers.Conv2DTranspose(32, (2, 2), strides=(2, 2), padding='same')(conv_7)
    upsample_8 = keras.layers.concatenate([upsample_8, conv_2])
    conv_8 = keras.layers.Conv2D(32, (3, 3), activation='relu', padding='same')(upsample_8)
    conv_8 = keras.layers.Dropout(0.1)(conv_8)
    conv_8 = keras.layers.Conv2D(32, (3, 3), activation='relu', padding='same')(conv_8)
    
    upsample_9 = keras.layers.Conv2DTranspose(16, (2, 2), strides=(2, 2), padding='same')(conv_8)
    upsample_9 = keras.layers.concatenate([upsample_9, conv_1])
    conv_9 = keras.layers.Conv2D(16, (3, 3), activation='relu', padding='same')(upsample_9)
    conv_9 = keras.layers.Dropout(0.1)(conv_9)
    conv_9 = keras.layers.Conv2D(16, (3, 3), activation='relu', padding='same')(conv_9)

    outputs = keras.layers.Conv2D(num_classes, (1, 1), activation='softmax')(conv_9)

    model = keras.models.Model(inputs=[input], outputs=[outputs])
    
    return model

# %%
standardUNet2D().summary()

# %%
dice_loss = sm.losses.DiceLoss()
focal_loss = sm.losses.CategoricalFocalLoss()
alpha = 0.5

total_loss = dice_loss + alpha * focal_loss
metrics = ['accuracy', sm.metrics.IOUScore(threshold=0.5)]
LR = 0.01

# %%
standardUNet2D_Model = standardUNet2D()
standardUNet2D_Model.compile (optimizer = 'adam', 
                              loss = 'categorical_crossentropy', 
                              metrics = metrics)

standardUNet2D_Model_history = standardUNet2D_Model.fit(X_train, y_train_cat, 
                                    batch_size = 64, 
                                    verbose=1, 
                                    epochs=50, 
                                    validation_data=(X_test, y_test_cat),
                                    shuffle=True)

# %%
#Define parameters for our model.

encoder_weights = 'imagenet'
BACKBONE = 'vgg16'  #Try vgg16, efficientnetb7, inceptionv3, resnet50
activation = 'softmax'
patch_size = 64
n_classes = 4
channels=3

LR = 0.0001
optim = tensorflow.keras.optimizers.Adam(LR)

# Segmentation models losses can be combined together by '+' and scaled by integer or float factor
# set class weights for dice_loss (car: 1.; pedestrian: 2.; background: 0.5;)
dice_loss = sm.losses.DiceLoss(class_weights=np.array([0.1, 0.3, 0.3, 0.3])) 
focal_loss = sm.losses.CategoricalFocalLoss()
total_loss = dice_loss + (1 * focal_loss)

# actulally total_loss can be imported directly from library, above example just show you how to manipulate with losses
# total_loss = sm.losses.binary_focal_dice_loss # or sm.losses.categorical_focal_dice_loss 

metrics = [sm.metrics.IOUScore(threshold=0.5), sm.metrics.FScore(threshold=0.5)]

# %%
preprocess_input = sm.get_preprocessing(BACKBONE)

# %%
#Preprocess input data - otherwise you end up with garbage resutls 
# and potentially model that does not converge.
X_train_prep = preprocess_input(X_train)
X_test_prep = preprocess_input(X_test)

# %%
#Define the model. Here we use Unet but we can also use other model architectures from the library.
model = sm.Unet(BACKBONE, classes=n_classes, 
                input_shape=(128, patch_size, patch_size, channels), 
                encoder_weights=encoder_weights,
                activation=activation)

model.compile(optimizer = optim, loss=total_loss, metrics=metrics)
print(model.summary())

# %%
#Fit the model
history=model.fit(X_train_prep, 
          y_train_cat,
          batch_size=4, 
          epochs=100,
          verbose=1,
          validation_data=(X_test_prep, y_test_cat))

# %%
def ResidualConvBlock(input, num_filters):
    conv_a = keras.layers.Conv2D(num_filters, (3, 3), padding='same')(input)
    conv_a = keras.layers.BatchNormalization(axis=3)(conv_a)
    conv_a = keras.layers.Activation('relu') (conv_a)

    conv_b = keras.layers.Conv2D(num_filters, (3, 3), padding='same')(conv_a)
    conv_b = keras.layers.BatchNormalization(axis=3)(conv_b)

    residual_conv = keras.layers.Conv2D(num_filters, kernel_size=(1, 1), padding='same')(input)
    residual_conv = keras.layers.BatchNormalization(axis=3)(residual_conv)

    result = keras.layers.add([residual_conv, conv_b])
    result = keras.layers.Activation('relu')(result)
    
    return result

# %%
def AttentionBlock(input, output_size, upsample_conv_block):
    conv_gate = keras.layers.Conv2D(output_size, (1, 1), padding='same')(input)
    conv_gate = keras.layers.BatchNormalization()(conv_gate)
    conv_gate = keras.layers.Activation('relu')(conv_gate)

    shape_upsample_conv_block = K.int_shape(upsample_conv_block)
    shape_conv_gate = K.int_shape(conv_gate)

    # Getting the x signal to the same shape as the gating signal
    upsample_conv_block_theta = keras.layers.Conv2D(output_size, (2, 2), strides=(2, 2), padding='same')(upsample_conv_block)
    shape_upsample_conv_block_theta = K.int_shape(upsample_conv_block_theta)

    # Getting the gating signal to the same number of filters as the inter_shape
    conv_gate = keras.layers.Conv2D(output_size, (1, 1), padding='same')(conv_gate)
    upsample_conv_gate = keras.layers.Conv2DTranspose(output_size, (3, 3), strides=(shape_upsample_conv_block_theta[1] // shape_conv_gate[1], shape_upsample_conv_block_theta[2] // shape_conv_gate[2]), padding='same')(conv_gate)

    concat_upsample_conv_gate = keras.layers.add([upsample_conv_gate, upsample_conv_block_theta])
    concat_upsample_conv_gate = keras.layers.Activation('relu')(concat_upsample_conv_gate)
    concat_upsample_conv_gate = keras.layers.Conv2D(1, (1, 1), padding='same')(concat_upsample_conv_gate)
    concat_upsample_conv_gate = keras.layers.Activation('sigmoid')(concat_upsample_conv_gate)
    shape_concat_upsample_conv_gate = K.int_shape(concat_upsample_conv_gate)    
    concat_upsample_conv_gate = keras.layers.UpSampling2D(size=(shape_upsample_conv_block[1] // shape_concat_upsample_conv_gate[1], shape_upsample_conv_block[2] // shape_concat_upsample_conv_gate[2]))(concat_upsample_conv_gate)
    concat_upsample_conv_gate = keras.layers.Lambda(lambda x, repnum: K.repeat_elements(x, shape_upsample_conv_block[3], axis=3),
                          arguments={'repnum': shape_upsample_conv_block[3]})(concat_upsample_conv_gate)
    
    result = keras.layers.multiply([concat_upsample_conv_gate, upsample_conv_block])
    result = keras.layers.Conv2D(shape_upsample_conv_block[3], (1, 1), padding='same')(result)
    result = keras.layers.BatchNormalization()(result)

    return result

# %%
def AttentionResUNet(img_h = 64, img_w = 64, img_ch = 3):
    input = keras.layers.Input((img_h, img_w, img_ch), dtype=tf.float32)
    
    res_conv_1 = ResidualConvBlock(input, 64)
    pool_1 = keras.layers.MaxPooling2D(pool_size=(2,2))(res_conv_1)

    res_conv_2 = ResidualConvBlock(pool_1, 128)
    pool_2 = keras.layers.MaxPooling2D(pool_size=(2,2))(res_conv_2)

    res_conv_3 = ResidualConvBlock(pool_2, 256)
    pool_3 = keras.layers.MaxPooling2D(pool_size=(2,2))(res_conv_3)

    res_conv_4 = ResidualConvBlock(pool_3, 512)
    pool_4 = keras.layers.MaxPooling2D(pool_size=(2,2))(res_conv_4)

    res_conv_5 = ResidualConvBlock(pool_4, 1024)

    att_1 = AttentionBlock(res_conv_5, 512, res_conv_4)
    up_conv_1 = keras.layers.UpSampling2D(size=(2, 2), data_format="channels_last")(res_conv_5)
    up_conv_1 = keras.layers.concatenate([up_conv_1, att_1], axis = 3)
    up_residual_conv_1 = ResidualConvBlock(up_conv_1, 512)
    
    att_2 = AttentionBlock(up_conv_1, 256, res_conv_3)
    up_conv_2 = keras.layers.UpSampling2D(size=(2, 2), data_format="channels_last")(up_residual_conv_1)
    up_conv_2 = keras.layers.concatenate([up_conv_2, att_2], axis = 3)
    up_residual_conv_2 = ResidualConvBlock(up_conv_2, 256)

    att_3 = AttentionBlock(up_conv_2, 128, res_conv_2)
    up_conv_3 = keras.layers.UpSampling2D(size=(2, 2), data_format="channels_last")(up_residual_conv_2)
    up_conv_3 = keras.layers.concatenate([up_conv_3, att_3], axis = 3)
    up_residual_conv_3 = ResidualConvBlock(up_conv_3, 128)

    att_4 = AttentionBlock(up_conv_3, 64, res_conv_1)
    up_conv_4 = keras.layers.UpSampling2D(size=(2, 2), data_format="channels_last")(up_residual_conv_3)
    up_conv_4 = keras.layers.concatenate([up_conv_4, att_4], axis = 3)
    up_residual_conv_4 = ResidualConvBlock(up_conv_4, 64)
    
    output = keras.layers.Conv2D(4, kernel_size=(1,1))(up_residual_conv_4)
    output = keras.layers.BatchNormalization(axis=3)(output)
    output = keras.layers.Activation('softmax')(output)

    model = keras.models.Model(input, output)
    return model

# %%
att_res_unet_model = AttentionResUNet()
print(att_res_unet_model.summary())

# %%
AttentionResUNet2D_Model = AttentionResUNet()
AttentionResUNet2D_Model.compile (optimizer = 'adam', 
                              loss = 'categorical_crossentropy', 
                              metrics = metrics)

AttentionResUNet2D_Model_history = AttentionResUNet2D_Model.fit(X_train, y_train_cat, 
                                    batch_size = 64, 
                                    verbose = 1, 
                                    epochs = 50, 
                                    validation_data = (X_test, y_test_cat),
                                    shuffle = True)

# %%
def ResidualConvBlock3D(input, num_filters):
    conv_a = keras.layers.Conv3D(num_filters, (2, 2, 2), padding='same')(input)
    conv_a = keras.layers.BatchNormalization(axis = 4)(conv_a)
    conv_a = keras.layers.Activation('relu') (conv_a)

    conv_b = keras.layers.Conv3D(num_filters, (2, 2, 2), padding='same')(conv_a)
    conv_b = keras.layers.BatchNormalization(axis = 4)(conv_b)

    residual_conv = keras.layers.Conv3D(num_filters, kernel_size=(1, 1, 1), padding='same')(input)
    residual_conv = keras.layers.BatchNormalization(axis = 4)(residual_conv)

    result = keras.layers.add([residual_conv, conv_b])
    result = keras.layers.Activation('relu')(result)
    
    return result

# %%
def AttentionBlock3D(input, output_size, upsample_conv_block):
    conv_gate = keras.layers.Conv3D(output_size, (1, 1, 1), padding='same')(input)
    conv_gate = keras.layers.BatchNormalization()(conv_gate)
    conv_gate = keras.layers.Activation('relu')(conv_gate)

    shape_upsample_conv_block = K.int_shape(upsample_conv_block)
    shape_conv_gate = K.int_shape(conv_gate)

    # Getting the x signal to the same shape as the gating signal
    upsample_conv_block_theta = keras.layers.Conv3D(output_size, (2, 2, 2), strides=(2, 2, 2), padding='same')(upsample_conv_block)
    shape_upsample_conv_block_theta = K.int_shape(upsample_conv_block_theta)

    # Getting the gating signal to the same number of filters as the inter_shape
    conv_gate = keras.layers.Conv3D(output_size, (2, 2, 2), padding='same')(conv_gate)
    upsample_conv_gate = keras.layers.Conv3DTranspose(output_size, (2, 2, 2), strides=(shape_upsample_conv_block_theta[1] // shape_conv_gate[1], shape_upsample_conv_block_theta[2] // shape_conv_gate[2], shape_upsample_conv_block_theta[3] // shape_conv_gate[3]), padding='same')(conv_gate)

    concat_upsample_conv_gate = keras.layers.add([upsample_conv_gate, upsample_conv_block_theta])
    concat_upsample_conv_gate = keras.layers.Activation('relu')(concat_upsample_conv_gate)
    concat_upsample_conv_gate = keras.layers.Conv3D(1, (2, 2, 2), padding='same')(concat_upsample_conv_gate)
    concat_upsample_conv_gate = keras.layers.Activation('sigmoid')(concat_upsample_conv_gate)
    shape_concat_upsample_conv_gate = K.int_shape(concat_upsample_conv_gate)    
    concat_upsample_conv_gate = keras.layers.UpSampling3D(size=(shape_upsample_conv_block[1] // shape_concat_upsample_conv_gate[1], shape_upsample_conv_block[2] // shape_concat_upsample_conv_gate[2], shape_upsample_conv_block[3] // shape_concat_upsample_conv_gate[3]))(concat_upsample_conv_gate)
    concat_upsample_conv_gate = keras.layers.Lambda(lambda x, repnum: K.repeat_elements(x, shape_upsample_conv_block[4], axis = 4),
                          arguments={'repnum': shape_upsample_conv_block[4]})(concat_upsample_conv_gate)
    
    result = keras.layers.multiply([concat_upsample_conv_gate, upsample_conv_block])
    result = keras.layers.Conv3D(shape_upsample_conv_block[4], (1, 1, 1), padding='same')(result)
    result = keras.layers.BatchNormalization()(result)

    return result

# %%
def AttentionResUNet3D(img_z = 128, img_h = 64, img_w = 64, img_ch = 3):
    input = keras.layers.Input((img_z, img_h, img_w, img_ch), dtype=tf.float32)
    
    res_conv_1 = ResidualConvBlock3D(input, 64)
    pool_1 = keras.layers.MaxPooling3D(pool_size=(2,2,2))(res_conv_1)

    res_conv_2 = ResidualConvBlock3D(pool_1, 128)
    pool_2 = keras.layers.MaxPooling3D(pool_size=(2,2,2))(res_conv_2)

    res_conv_3 = ResidualConvBlock3D(pool_2, 256)
    pool_3 = keras.layers.MaxPooling3D(pool_size=(2,2,2))(res_conv_3)

    res_conv_4 = ResidualConvBlock3D(pool_3, 512)
    pool_4 = keras.layers.MaxPooling3D(pool_size=(2,2,2))(res_conv_4)

    res_conv_5 = ResidualConvBlock3D(pool_4, 1024)

    att_1 = AttentionBlock3D(res_conv_5, 512, res_conv_4)
    up_conv_1 = keras.layers.UpSampling3D(size=(2, 2, 2), data_format="channels_last")(res_conv_5)
    up_conv_1 = keras.layers.concatenate([up_conv_1, att_1], axis = 4)
    up_residual_conv_1 = ResidualConvBlock3D(up_conv_1, 512)
    
    att_2 = AttentionBlock3D(up_conv_1, 256, res_conv_3)
    up_conv_2 = keras.layers.UpSampling3D(size=(2, 2, 2), data_format="channels_last")(up_residual_conv_1)
    up_conv_2 = keras.layers.concatenate([up_conv_2, att_2], axis = 4)
    up_residual_conv_2 = ResidualConvBlock3D(up_conv_2, 256)

    att_3 = AttentionBlock3D(up_conv_2, 128, res_conv_2)
    up_conv_3 = keras.layers.UpSampling3D(size=(2, 2, 2), data_format="channels_last")(up_residual_conv_2)
    up_conv_3 = keras.layers.concatenate([up_conv_3, att_3], axis = 4)
    up_residual_conv_3 = ResidualConvBlock3D(up_conv_3, 128)

    att_4 = AttentionBlock3D(up_conv_3, 64, res_conv_1)
    up_conv_4 = keras.layers.UpSampling3D(size=(2, 2, 2), data_format="channels_last")(up_residual_conv_3)
    up_conv_4 = keras.layers.concatenate([up_conv_4, att_4], axis = 4)
    up_residual_conv_4 = ResidualConvBlock3D(up_conv_4, 64)
    
    output = keras.layers.Conv3D(4, kernel_size=(1, 1,1))(up_residual_conv_4)
    output = keras.layers.BatchNormalization(axis = 4)(output)
    output = keras.layers.Activation('softmax')(output)

    model = keras.models.Model(input, output)
    return model

# %%
AttentionResUNet3D().summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 128, 64, 64, 0
# __________________________________________________________________________________________________
# conv3d (Conv3D)                 (None, 128, 64, 64,  1600        input_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 128, 64, 64,  256         conv3d[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 128, 64, 64,  0           batch_normalization[0][0]
# __________________________________________________________________________________________________
# conv3d_2 (Conv3D)               (None, 128, 64, 64,  256         input_1[0][0]
# __________________________________________________________________________________________________
# conv3d_1 (Conv3D)               (None, 128, 64, 64,  32832       activation[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 128, 64, 64,  256         conv3d_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 128, 64, 64,  256         conv3d_1[0][0]
# __________________________________________________________________________________________________
# add (Add)                       (None, 128, 64, 64,  0           batch_normalization_2[0][0]
#                                                                  batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 128, 64, 64,  0           add[0][0]
# __________________________________________________________________________________________________
# max_pooling3d (MaxPooling3D)    (None, 64, 32, 32, 6 0           activation_1[0][0]
# __________________________________________________________________________________________________
# conv3d_3 (Conv3D)               (None, 64, 32, 32, 1 65664       max_pooling3d[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 64, 32, 32, 1 512         conv3d_3[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 64, 32, 32, 1 0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# conv3d_5 (Conv3D)               (None, 64, 32, 32, 1 8320        max_pooling3d[0][0]
# __________________________________________________________________________________________________
# conv3d_4 (Conv3D)               (None, 64, 32, 32, 1 131200      activation_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 64, 32, 32, 1 512         conv3d_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 64, 32, 32, 1 512         conv3d_4[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 64, 32, 32, 1 0           batch_normalization_5[0][0]
#                                                                  batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 64, 32, 32, 1 0           add_1[0][0]
# __________________________________________________________________________________________________
# max_pooling3d_1 (MaxPooling3D)  (None, 32, 16, 16, 1 0           activation_3[0][0]
# __________________________________________________________________________________________________
# conv3d_6 (Conv3D)               (None, 32, 16, 16, 2 262400      max_pooling3d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 32, 16, 16, 2 1024        conv3d_6[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 32, 16, 16, 2 0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# conv3d_8 (Conv3D)               (None, 32, 16, 16, 2 33024       max_pooling3d_1[0][0]
# __________________________________________________________________________________________________
# conv3d_7 (Conv3D)               (None, 32, 16, 16, 2 524544      activation_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 32, 16, 16, 2 1024        conv3d_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 32, 16, 16, 2 1024        conv3d_7[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 32, 16, 16, 2 0           batch_normalization_8[0][0]
#                                                                  batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 32, 16, 16, 2 0           add_2[0][0]
# __________________________________________________________________________________________________
# max_pooling3d_2 (MaxPooling3D)  (None, 16, 8, 8, 256 0           activation_5[0][0]
# __________________________________________________________________________________________________
# conv3d_9 (Conv3D)               (None, 16, 8, 8, 512 1049088     max_pooling3d_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 16, 8, 8, 512 2048        conv3d_9[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 16, 8, 8, 512 0           batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# conv3d_11 (Conv3D)              (None, 16, 8, 8, 512 131584      max_pooling3d_2[0][0]
# __________________________________________________________________________________________________
# conv3d_10 (Conv3D)              (None, 16, 8, 8, 512 2097664     activation_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 16, 8, 8, 512 2048        conv3d_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 16, 8, 8, 512 2048        conv3d_10[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 16, 8, 8, 512 0           batch_normalization_11[0][0]
#                                                                  batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 16, 8, 8, 512 0           add_3[0][0]
# __________________________________________________________________________________________________
# max_pooling3d_3 (MaxPooling3D)  (None, 8, 4, 4, 512) 0           activation_7[0][0]
# __________________________________________________________________________________________________
# conv3d_12 (Conv3D)              (None, 8, 4, 4, 1024 4195328     max_pooling3d_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 8, 4, 4, 1024 4096        conv3d_12[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 8, 4, 4, 1024 0           batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# conv3d_14 (Conv3D)              (None, 8, 4, 4, 1024 525312      max_pooling3d_3[0][0]
# __________________________________________________________________________________________________
# conv3d_13 (Conv3D)              (None, 8, 4, 4, 1024 8389632     activation_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 8, 4, 4, 1024 4096        conv3d_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 8, 4, 4, 1024 4096        conv3d_13[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 8, 4, 4, 1024 0           batch_normalization_14[0][0]
#                                                                  batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 8, 4, 4, 1024 0           add_4[0][0]
# __________________________________________________________________________________________________
# conv3d_15 (Conv3D)              (None, 8, 4, 4, 512) 524800      activation_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 8, 4, 4, 512) 2048        conv3d_15[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 8, 4, 4, 512) 0           batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# conv3d_17 (Conv3D)              (None, 8, 4, 4, 512) 2097664     activation_10[0][0]
# __________________________________________________________________________________________________
# conv3d_transpose (Conv3DTranspo (None, 8, 4, 4, 512) 2097664     conv3d_17[0][0]
# __________________________________________________________________________________________________
# conv3d_16 (Conv3D)              (None, 8, 4, 4, 512) 2097664     activation_7[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, 8, 4, 4, 512) 0           conv3d_transpose[0][0]
#                                                                  conv3d_16[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 8, 4, 4, 512) 0           add_5[0][0]
# __________________________________________________________________________________________________
# conv3d_18 (Conv3D)              (None, 8, 4, 4, 1)   4097        activation_11[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 8, 4, 4, 1)   0           conv3d_18[0][0]
# __________________________________________________________________________________________________
# up_sampling3d (UpSampling3D)    (None, 16, 8, 8, 1)  0           activation_12[0][0]
# __________________________________________________________________________________________________
# lambda (Lambda)                 (None, 16, 8, 8, 512 0           up_sampling3d[0][0]
# __________________________________________________________________________________________________
# multiply (Multiply)             (None, 16, 8, 8, 512 0           lambda[0][0]
#                                                                  activation_7[0][0]
# __________________________________________________________________________________________________
# conv3d_19 (Conv3D)              (None, 16, 8, 8, 512 262656      multiply[0][0]
# __________________________________________________________________________________________________
# up_sampling3d_1 (UpSampling3D)  (None, 16, 8, 8, 102 0           activation_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 16, 8, 8, 512 2048        conv3d_19[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 16, 8, 8, 153 0           up_sampling3d_1[0][0]
#                                                                  batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# conv3d_23 (Conv3D)              (None, 16, 8, 8, 256 393472      concatenate[0][0]
# __________________________________________________________________________________________________
# batch_normalization_20 (BatchNo (None, 16, 8, 8, 256 1024        conv3d_23[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, 16, 8, 8, 256 0           batch_normalization_20[0][0]
# __________________________________________________________________________________________________
# conv3d_25 (Conv3D)              (None, 16, 8, 8, 256 524544      activation_15[0][0]
# __________________________________________________________________________________________________
# conv3d_transpose_1 (Conv3DTrans (None, 16, 8, 8, 256 524544      conv3d_25[0][0]
# __________________________________________________________________________________________________
# conv3d_24 (Conv3D)              (None, 16, 8, 8, 256 524544      activation_5[0][0]
# __________________________________________________________________________________________________
# add_7 (Add)                     (None, 16, 8, 8, 256 0           conv3d_transpose_1[0][0]
#                                                                  conv3d_24[0][0]
# __________________________________________________________________________________________________
# conv3d_20 (Conv3D)              (None, 16, 8, 8, 512 6291968     concatenate[0][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, 16, 8, 8, 256 0           add_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, 16, 8, 8, 512 2048        conv3d_20[0][0]
# __________________________________________________________________________________________________
# conv3d_26 (Conv3D)              (None, 16, 8, 8, 1)  2049        activation_16[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 16, 8, 8, 512 0           batch_normalization_17[0][0]
# __________________________________________________________________________________________________
# activation_17 (Activation)      (None, 16, 8, 8, 1)  0           conv3d_26[0][0]
# __________________________________________________________________________________________________
# conv3d_22 (Conv3D)              (None, 16, 8, 8, 512 786944      concatenate[0][0]
# __________________________________________________________________________________________________
# conv3d_21 (Conv3D)              (None, 16, 8, 8, 512 2097664     activation_13[0][0]
# __________________________________________________________________________________________________
# up_sampling3d_2 (UpSampling3D)  (None, 32, 16, 16, 1 0           activation_17[0][0]
# __________________________________________________________________________________________________
# batch_normalization_19 (BatchNo (None, 16, 8, 8, 512 2048        conv3d_22[0][0]
# __________________________________________________________________________________________________
# batch_normalization_18 (BatchNo (None, 16, 8, 8, 512 2048        conv3d_21[0][0]
# __________________________________________________________________________________________________
# lambda_1 (Lambda)               (None, 32, 16, 16, 2 0           up_sampling3d_2[0][0]
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, 16, 8, 8, 512 0           batch_normalization_19[0][0]
#                                                                  batch_normalization_18[0][0]
# __________________________________________________________________________________________________
# multiply_1 (Multiply)           (None, 32, 16, 16, 2 0           lambda_1[0][0]
#                                                                  activation_5[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, 16, 8, 8, 512 0           add_6[0][0]
# __________________________________________________________________________________________________
# conv3d_27 (Conv3D)              (None, 32, 16, 16, 2 65792       multiply_1[0][0]
# __________________________________________________________________________________________________
# up_sampling3d_3 (UpSampling3D)  (None, 32, 16, 16, 5 0           activation_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_21 (BatchNo (None, 32, 16, 16, 2 1024        conv3d_27[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 32, 16, 16, 7 0           up_sampling3d_3[0][0]
#                                                                  batch_normalization_21[0][0]
# __________________________________________________________________________________________________
# conv3d_31 (Conv3D)              (None, 32, 16, 16, 1 98432       concatenate_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_25 (BatchNo (None, 32, 16, 16, 1 512         conv3d_31[0][0]
# __________________________________________________________________________________________________
# activation_20 (Activation)      (None, 32, 16, 16, 1 0           batch_normalization_25[0][0]
# __________________________________________________________________________________________________
# conv3d_33 (Conv3D)              (None, 32, 16, 16, 1 131200      activation_20[0][0]
# __________________________________________________________________________________________________
# conv3d_transpose_2 (Conv3DTrans (None, 32, 16, 16, 1 131200      conv3d_33[0][0]
# __________________________________________________________________________________________________
# conv3d_32 (Conv3D)              (None, 32, 16, 16, 1 131200      activation_3[0][0]
# __________________________________________________________________________________________________
# add_9 (Add)                     (None, 32, 16, 16, 1 0           conv3d_transpose_2[0][0]
#                                                                  conv3d_32[0][0]
# __________________________________________________________________________________________________
# conv3d_28 (Conv3D)              (None, 32, 16, 16, 2 1573120     concatenate_1[0][0]
# __________________________________________________________________________________________________
# activation_21 (Activation)      (None, 32, 16, 16, 1 0           add_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_22 (BatchNo (None, 32, 16, 16, 2 1024        conv3d_28[0][0]
# __________________________________________________________________________________________________
# conv3d_34 (Conv3D)              (None, 32, 16, 16, 1 1025        activation_21[0][0]
# __________________________________________________________________________________________________
# activation_18 (Activation)      (None, 32, 16, 16, 2 0           batch_normalization_22[0][0]
# __________________________________________________________________________________________________
# activation_22 (Activation)      (None, 32, 16, 16, 1 0           conv3d_34[0][0]
# __________________________________________________________________________________________________
# conv3d_30 (Conv3D)              (None, 32, 16, 16, 2 196864      concatenate_1[0][0]
# __________________________________________________________________________________________________
# conv3d_29 (Conv3D)              (None, 32, 16, 16, 2 524544      activation_18[0][0]
# __________________________________________________________________________________________________
# up_sampling3d_4 (UpSampling3D)  (None, 64, 32, 32, 1 0           activation_22[0][0]
# __________________________________________________________________________________________________
# batch_normalization_24 (BatchNo (None, 32, 16, 16, 2 1024        conv3d_30[0][0]
# __________________________________________________________________________________________________
# batch_normalization_23 (BatchNo (None, 32, 16, 16, 2 1024        conv3d_29[0][0]
# __________________________________________________________________________________________________
# lambda_2 (Lambda)               (None, 64, 32, 32, 1 0           up_sampling3d_4[0][0]
# __________________________________________________________________________________________________
# add_8 (Add)                     (None, 32, 16, 16, 2 0           batch_normalization_24[0][0]
#                                                                  batch_normalization_23[0][0]
# __________________________________________________________________________________________________
# multiply_2 (Multiply)           (None, 64, 32, 32, 1 0           lambda_2[0][0]
#                                                                  activation_3[0][0]
# __________________________________________________________________________________________________
# activation_19 (Activation)      (None, 32, 16, 16, 2 0           add_8[0][0]
# __________________________________________________________________________________________________
# conv3d_35 (Conv3D)              (None, 64, 32, 32, 1 16512       multiply_2[0][0]
# __________________________________________________________________________________________________
# up_sampling3d_5 (UpSampling3D)  (None, 64, 32, 32, 2 0           activation_19[0][0]
# __________________________________________________________________________________________________
# batch_normalization_26 (BatchNo (None, 64, 32, 32, 1 512         conv3d_35[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 64, 32, 32, 3 0           up_sampling3d_5[0][0]
#                                                                  batch_normalization_26[0][0]
# __________________________________________________________________________________________________
# conv3d_39 (Conv3D)              (None, 64, 32, 32, 6 24640       concatenate_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_30 (BatchNo (None, 64, 32, 32, 6 256         conv3d_39[0][0]
# __________________________________________________________________________________________________
# activation_25 (Activation)      (None, 64, 32, 32, 6 0           batch_normalization_30[0][0]
# __________________________________________________________________________________________________
# conv3d_41 (Conv3D)              (None, 64, 32, 32, 6 32832       activation_25[0][0]
# __________________________________________________________________________________________________
# conv3d_transpose_3 (Conv3DTrans (None, 64, 32, 32, 6 32832       conv3d_41[0][0]
# __________________________________________________________________________________________________
# conv3d_40 (Conv3D)              (None, 64, 32, 32, 6 32832       activation_1[0][0]
# __________________________________________________________________________________________________
# add_11 (Add)                    (None, 64, 32, 32, 6 0           conv3d_transpose_3[0][0]
#                                                                  conv3d_40[0][0]
# __________________________________________________________________________________________________
# conv3d_36 (Conv3D)              (None, 64, 32, 32, 1 393344      concatenate_2[0][0]
# __________________________________________________________________________________________________
# activation_26 (Activation)      (None, 64, 32, 32, 6 0           add_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_27 (BatchNo (None, 64, 32, 32, 1 512         conv3d_36[0][0]
# __________________________________________________________________________________________________
# conv3d_42 (Conv3D)              (None, 64, 32, 32, 1 513         activation_26[0][0]
# __________________________________________________________________________________________________
# activation_23 (Activation)      (None, 64, 32, 32, 1 0           batch_normalization_27[0][0]
# __________________________________________________________________________________________________
# activation_27 (Activation)      (None, 64, 32, 32, 1 0           conv3d_42[0][0]
# __________________________________________________________________________________________________
# conv3d_38 (Conv3D)              (None, 64, 32, 32, 1 49280       concatenate_2[0][0]
# __________________________________________________________________________________________________
# conv3d_37 (Conv3D)              (None, 64, 32, 32, 1 131200      activation_23[0][0]
# __________________________________________________________________________________________________
# up_sampling3d_6 (UpSampling3D)  (None, 128, 64, 64,  0           activation_27[0][0]
# __________________________________________________________________________________________________
# batch_normalization_29 (BatchNo (None, 64, 32, 32, 1 512         conv3d_38[0][0]
# __________________________________________________________________________________________________
# batch_normalization_28 (BatchNo (None, 64, 32, 32, 1 512         conv3d_37[0][0]
# __________________________________________________________________________________________________
# lambda_3 (Lambda)               (None, 128, 64, 64,  0           up_sampling3d_6[0][0]
# __________________________________________________________________________________________________
# add_10 (Add)                    (None, 64, 32, 32, 1 0           batch_normalization_29[0][0]
#                                                                  batch_normalization_28[0][0]
# __________________________________________________________________________________________________
# multiply_3 (Multiply)           (None, 128, 64, 64,  0           lambda_3[0][0]
#                                                                  activation_1[0][0]
# __________________________________________________________________________________________________
# activation_24 (Activation)      (None, 64, 32, 32, 1 0           add_10[0][0]
# __________________________________________________________________________________________________
# conv3d_43 (Conv3D)              (None, 128, 64, 64,  4160        multiply_3[0][0]
# __________________________________________________________________________________________________
# up_sampling3d_7 (UpSampling3D)  (None, 128, 64, 64,  0           activation_24[0][0]
# __________________________________________________________________________________________________
# batch_normalization_31 (BatchNo (None, 128, 64, 64,  256         conv3d_43[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 128, 64, 64,  0           up_sampling3d_7[0][0]
#                                                                  batch_normalization_31[0][0]
# __________________________________________________________________________________________________
# conv3d_44 (Conv3D)              (None, 128, 64, 64,  98368       concatenate_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_32 (BatchNo (None, 128, 64, 64,  256         conv3d_44[0][0]
# __________________________________________________________________________________________________
# activation_28 (Activation)      (None, 128, 64, 64,  0           batch_normalization_32[0][0]
# __________________________________________________________________________________________________
# conv3d_46 (Conv3D)              (None, 128, 64, 64,  12352       concatenate_3[0][0]
# __________________________________________________________________________________________________
# conv3d_45 (Conv3D)              (None, 128, 64, 64,  32832       activation_28[0][0]
# __________________________________________________________________________________________________
# batch_normalization_34 (BatchNo (None, 128, 64, 64,  256         conv3d_46[0][0]
# __________________________________________________________________________________________________
# batch_normalization_33 (BatchNo (None, 128, 64, 64,  256         conv3d_45[0][0]
# __________________________________________________________________________________________________
# add_12 (Add)                    (None, 128, 64, 64,  0           batch_normalization_34[0][0]
#                                                                  batch_normalization_33[0][0]
# __________________________________________________________________________________________________
# activation_29 (Activation)      (None, 128, 64, 64,  0           add_12[0][0]
# __________________________________________________________________________________________________
# conv3d_47 (Conv3D)              (None, 128, 64, 64,  260         activation_29[0][0]
# __________________________________________________________________________________________________
# batch_normalization_35 (BatchNo (None, 128, 64, 64,  16          conv3d_47[0][0]
# __________________________________________________________________________________________________
# activation_30 (Activation)      (None, 128, 64, 64,  0           batch_normalization_35[0][0]
# ==================================================================================================
# Total params: 39,437,080
# Trainable params: 39,415,568
# Non-trainable params: 21,512
# __________________________________________________________________________________________________

# %%
y_train_cat = to_categorical(y_train, num_classes = 4)
y_test_cat = to_categorical(y_test, num_classes = 4)

# %%
dice_loss = sm.losses.DiceLoss()
focal_loss = sm.losses.CategoricalFocalLoss()
alpha = 0.5

total_loss = dice_loss + alpha * focal_loss
metrics = ['accuracy', sm.metrics.IOUScore(threshold=0.5)]
LR = 0.01

# %%
X_train.shape
# Out:
# (24, 128, 64, 64, 3)

# %%
y_train.shape
# Out:
# (24, 128, 64, 64)

# %%
AttentionResUNet3D_Model = AttentionResUNet3D()

# %%
opt = tf.keras.optimizers.Adam(learning_rate=0.005)
AttentionResUNet3D_Model.compile (optimizer = opt, 
                              loss = total_loss, 
                              metrics = metrics)

AttentionResUNet3D_Model_history = AttentionResUNet3D_Model.fit(X_train, y_train_cat, 
                                    batch_size = 1, 
                                    verbose = 1, 
                                    epochs = 1000, 
                                    validation_data = (X_test, y_test_cat),
                                    shuffle = True)
# Out:
# Epoch 1/1000
# 24/24 [==============================] - 64s 2s/step - loss: 0.1986 - accuracy: 0.9854 - iou_score: 0.7113 - val_loss: 0.3982 - val_accuracy: 0.9757 - val_iou_score: 0.5052
# Epoch 2/1000
# 24/24 [==============================] - 51s 2s/step - loss: 0.1962 - accuracy: 0.9855 - iou_score: 0.7143 - val_loss: 0.4069 - val_accuracy: 0.9747 - val_iou_score: 0.4948
# Epoch 3/1000
# 24/24 [==============================] - 53s 2s/step - loss: 0.1944 - accuracy: 0.9859 - iou_score: 0.7165 - val_loss: 0.4494 - val_accuracy: 0.9720 - val_iou_score: 0.4593
# Epoch 4/1000
# 24/24 [==============================] - 51s 2s/step - loss: 0.1937 - accuracy: 0.9859 - iou_score: 0.7174 - val_loss: 0.3986 - val_accuracy: 0.9749 - val_iou_score: 0.5024
# Epoch 5/1000
# 24/24 [==============================] - 51s 2s/step - loss: 0.1933 - accuracy: 0.9860 - iou_score: 0.7178 - val_loss: 0.4270 - val_accuracy: 0.9735 - val_iou_score: 0.4784
# Epoch 6/1000
# 24/24 [==============================] - 51s 2s/step - loss: 0.1921 - accuracy: 0.9861 - iou_score: 0.7194 - val_loss: 0.4298 - val_accuracy: 0.9734 - val_iou_score: 0.4760
# Epoch 7/1000
# 24/24 [==============================] - 51s 2s/step - loss: 0.1916 - accuracy: 0.9862 - iou_score: 0.7201 - val_loss: 0.4259 - val_accuracy: 0.9738 - val_iou_score: 0.4790
# Epoch 8/1000
# 24/24 [==============================] - 51s 2s/step - loss: 0.1921 - accuracy: 0.9862 - iou_score: 0.7194 - val_loss: 0.4096 - val_accuracy: 0.9739 - val_iou_score: 0.4930
# Epoch 9/1000
# 24/24 [==============================] - 51s 2s/step - loss: 0.1922 - accuracy: 0.9862 - iou_score: 0.7193 - val_loss: 0.3727 - val_accuracy: 0.9765 - val_iou_score: 0.5262
# Epoch 10/1000
# 24/24 [==============================] - 51s 2s/step - loss: 0.1916 - accuracy: 0.9862 - iou_score: 0.7200 - val_loss: 0.4277 - val_accuracy: 0.9736 - val_iou_score: 0.4767
# Epoch 11/1000
# 24/24 [==============================] - 51s 2s/step - loss: 0.1921 - accuracy: 0.9862 - iou_score: 0.7194 - val_loss: 0.3782 - val_accuracy: 0.9758 - val_iou_score: 0.5191
# Epoch 12/1000
# 24/24 [==============================] - 51s 2s/step - loss: 0.1911 - accuracy: 0.9864 - iou_score: 0.7208 - val_loss: 0.4112 - val_accuracy: 0.9748 - val_iou_score: 0.4906
# Epoch 13/1000
# 24/24 [==============================] - 51s 2s/step - loss: 0.1907 - accuracy: 0.9863 - iou_score: 0.7210 - val_loss: 0.4044 - val_accuracy: 0.9747 - val_iou_score: 0.4958
# Epoch 14/1000
# 24/24 [==============================] - 51s 2s/step - loss: 0.1902 - accuracy: 0.9864 - iou_score: 0.7216 - val_loss: 0.3721 - val_accuracy: 0.9761 - val_iou_score: 0.5252
# Epoch 15/1000
# 24/24 [==============================] - 51s 2s/step - loss: 0.1899 - accuracy: 0.9863 - iou_score: 0.7216 - val_loss: 0.3930 - val_accuracy: 0.9760 - val_iou_score: 0.5075
# Epoch 16/1000
# 24/24 [==============================] - 51s 2s/step - loss: 0.1895 - accuracy: 0.9863 - iou_score: 0.7223 - val_loss: 0.4007 - val_accuracy: 0.9751 - val_iou_score: 0.4992
# Epoch 17/1000
# 24/24 [==============================] - 53s 2s/step - loss: 0.1881 - accuracy: 0.9865 - iou_score: 0.7239 - val_loss: 0.4058 - val_accuracy: 0.9748 - val_iou_score: 0.4952
# Epoch 18/1000
# 24/24 [==============================] - 53s 2s/step - loss: 0.1881 - accuracy: 0.9865 - iou_score: 0.7240 - val_loss: 0.3733 - val_accuracy: 0.9759 - val_iou_score: 0.5255
# Epoch 19/1000
# 24/24 [==============================] - 51s 2s/step - loss: 0.1872 - accuracy: 0.9866 - iou_score: 0.7246 - val_loss: 0.3994 - val_accuracy: 0.9752 - val_iou_score: 0.5008
# Epoch 20/1000
# 24/24 [==============================] - 51s 2s/step - loss: 0.1864 - accuracy: 0.9864 - iou_score: 0.7255 - val_loss: 0.3820 - val_accuracy: 0.9764 - val_iou_score: 0.5163
# Epoch 21/1000
# 24/24 [==============================] - 53s 2s/step - loss: 0.1852 - accuracy: 0.9865 - iou_score: 0.7268 - val_loss: 0.4235 - val_accuracy: 0.9737 - val_iou_score: 0.4783
# Epoch 22/1000
# 24/24 [==============================] - 51s 2s/step - loss: 0.1849 - accuracy: 0.9865 - iou_score: 0.7273 - val_loss: 0.4113 - val_accuracy: 0.9752 - val_iou_score: 0.4915
# Epoch 23/1000
# 24/24 [==============================] - 53s 2s/step - loss: 0.1840 - accuracy: 0.9866 - iou_score: 0.7283 - val_loss: 0.3842 - val_accuracy: 0.9764 - val_iou_score: 0.5124
# Epoch 24/1000
# 24/24 [==============================] - 51s 2s/step - loss: 0.1828 - accuracy: 0.9867 - iou_score: 0.7294 - val_loss: 0.4051 - val_accuracy: 0.9751 - val_iou_score: 0.4935
# Epoch 25/1000
# 24/24 [==============================] - 51s 2s/step - loss: 0.1828 - accuracy: 0.9867 - iou_score: 0.7295 - val_loss: 0.4260 - val_accuracy: 0.9748 - val_iou_score: 0.4780
# Epoch 26/1000
# 24/24 [==============================] - 53s 2s/step - loss: 0.1824 - accuracy: 0.9866 - iou_score: 0.7296 - val_loss: 0.3870 - val_accuracy: 0.9760 - val_iou_score: 0.5111
# Epoch 27/1000
# 24/24 [==============================] - 51s 2s/step - loss: 0.1827 - accuracy: 0.9868 - iou_score: 0.7295 - val_loss: 0.3645 - val_accuracy: 0.9769 - val_iou_score: 0.5320
# Epoch 28/1000
# 24/24 [==============================] - 51s 2s/step - loss: 0.1808 - accuracy: 0.9866 - iou_score: 0.7315 - val_loss: 0.4082 - val_accuracy: 0.9744 - val_iou_score: 0.4933
# Epoch 29/1000
# 24/24 [==============================] - 53s 2s/step - loss: 0.1798 - accuracy: 0.9868 - iou_score: 0.7325 - val_loss: 0.4194 - val_accuracy: 0.9740 - val_iou_score: 0.4828
# Epoch 30/1000
# 24/24 [==============================] - 51s 2s/step - loss: 0.1796 - accuracy: 0.9868 - iou_score: 0.7331 - val_loss: 0.3863 - val_accuracy: 0.9756 - val_iou_score: 0.5121
# Epoch 31/1000
# 24/24 [==============================] - 51s 2s/step - loss: 0.1824 - accuracy: 0.9865 - iou_score: 0.7291 - val_loss: 0.3897 - val_accuracy: 0.9753 - val_iou_score: 0.5069
# Epoch 32/1000
# 24/24 [==============================] - 51s 2s/step - loss: 0.1795 - accuracy: 0.9867 - iou_score: 0.7329 - val_loss: 0.3853 - val_accuracy: 0.9756 - val_iou_score: 0.5125
# Epoch 33/1000
# 24/24 [==============================] - 51s 2s/step - loss: 0.1770 - accuracy: 0.9868 - iou_score: 0.7356 - val_loss: 0.3568 - val_accuracy: 0.9774 - val_iou_score: 0.5373
# Epoch 34/1000
# 24/24 [==============================] - 53s 2s/step - loss: 0.1760 - accuracy: 0.9871 - iou_score: 0.7369 - val_loss: 0.4164 - val_accuracy: 0.9744 - val_iou_score: 0.4854
# Epoch 35/1000
# 24/24 [==============================] - 51s 2s/step - loss: 0.1741 - accuracy: 0.9870 - iou_score: 0.7391 - val_loss: 0.4108 - val_accuracy: 0.9751 - val_iou_score: 0.4897
# Epoch 36/1000
# 24/24 [==============================] - 51s 2s/step - loss: 0.1755 - accuracy: 0.9871 - iou_score: 0.7372 - val_loss: 0.3838 - val_accuracy: 0.9764 - val_iou_score: 0.5143
# Epoch 37/1000
# 24/24 [==============================] - 51s 2s/step - loss: 0.1758 - accuracy: 0.9870 - iou_score: 0.7369 - val_loss: 0.3897 - val_accuracy: 0.9755 - val_iou_score: 0.5087
# Epoch 38/1000
# 24/24 [==============================] - 51s 2s/step - loss: 0.1791 - accuracy: 0.9867 - iou_score: 0.7329 - val_loss: 0.3963 - val_accuracy: 0.9748 - val_iou_score: 0.5020
# Epoch 39/1000
# 24/24 [==============================] - 53s 2s/step - loss: 0.1799 - accuracy: 0.9863 - iou_score: 0.7316 - val_loss: 0.3985 - val_accuracy: 0.9754 - val_iou_score: 0.5022
# Epoch 40/1000
# 24/24 [==============================] - 51s 2s/step - loss: 0.1787 - accuracy: 0.9867 - iou_score: 0.7340 - val_loss: 0.3510 - val_accuracy: 0.9772 - val_iou_score: 0.5436
# Epoch 41/1000
# 24/24 [==============================] - 53s 2s/step - loss: 0.1743 - accuracy: 0.9870 - iou_score: 0.7387 - val_loss: 0.3784 - val_accuracy: 0.9755 - val_iou_score: 0.5190
# Epoch 42/1000
# 24/24 [==============================] - 53s 2s/step - loss: 0.1729 - accuracy: 0.9872 - iou_score: 0.7403 - val_loss: 0.3820 - val_accuracy: 0.9763 - val_iou_score: 0.5168
# Epoch 43/1000
# 24/24 [==============================] - 51s 2s/step - loss: 0.1705 - accuracy: 0.9873 - iou_score: 0.7430 - val_loss: 0.3986 - val_accuracy: 0.9755 - val_iou_score: 0.5010
# Epoch 44/1000
# 24/24 [==============================] - 51s 2s/step - loss: 0.1697 - accuracy: 0.9875 - iou_score: 0.7441 - val_loss: 0.4133 - val_accuracy: 0.9742 - val_iou_score: 0.4865
# Epoch 45/1000
# 24/24 [==============================] - 51s 2s/step - loss: 0.1696 - accuracy: 0.9875 - iou_score: 0.7443 - val_loss: 0.4015 - val_accuracy: 0.9746 - val_iou_score: 0.4983
# Epoch 46/1000
# 10/24 [===========>..................] - ETA: 27s - loss: 0.1669 - accuracy: 0.9865 - iou_score: 0.7501
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-32-af640caf24a0> in <module>()
#       9                                     epochs = 1000,
#      10                                     validation_data = (X_test, y_test_cat),
# ---> 11                                     shuffle = True)
#
# /usr/local/lib/python3.7/dist-packages/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1182                 _r=1):
#    1183               callbacks.on_train_batch_begin(step)
# -> 1184               tmp_logs = self.train_function(iterator)
#    1185               if data_handler.should_sync:
#    1186                 context.async_wait()
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/def_function.py in __call__(self, *args, **kwds)
#     883
#     884       with OptionalXlaContext(self._jit_compile):
# --> 885         result = self._call(*args, **kwds)
#     886
#     887       new_tracing_count = self.experimental_get_tracing_count()
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/def_function.py in _call(self, *args, **kwds)
#     915       # In this case we have created variables on the first call, so we run the
#     916       # defunned version which is guaranteed to never create variables.
# --> 917       return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     918     elif self._stateful_fn is not None:
#     919       # Release the lock early so that multiple threads can perform the call
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/function.py in __call__(self, *args, **kwargs)
#    3038        filtered_flat_args) = self._maybe_define_function(args, kwargs)
#    3039     return graph_function._call_flat(
# -> 3040         filtered_flat_args, captured_inputs=graph_function.captured_inputs)  # pylint: disable=protected-access
#    3041
#    3042   @property
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1962       # No tape is watching; skip to running the function.
#    1963       return self._build_call_outputs(self._inference_function.call(
# -> 1964           ctx, args, cancellation_manager=cancellation_manager))
#    1965     forward_backward = self._select_forward_and_backward_functions(
#    1966         args,
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/function.py in call(self, ctx, args, cancellation_manager)
#     594               inputs=args,
#     595               attrs=attrs,
# --> 596               ctx=ctx)
#     597         else:
#     598           outputs = execute.execute_with_cancellation(
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      58     ctx.ensure_initialized()
#      59     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
# ---> 60                                         inputs, attrs, num_outputs)
#      61   except core._NotOkStatusException as e:
#      62     if name is not None:
#
# KeyboardInterrupt:
